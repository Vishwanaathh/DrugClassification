# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import tensorflow as tf
tf.random.set_seed(3)
from tensorflow import keras

# %%
data=pd.read_csv('/content/drug200.csv')

# %%
data.head()
# Out:
#    Age Sex      BP Cholesterol  Na_to_K   Drug
# 0   23   F    HIGH        HIGH   25.355  DrugY
# 1   47   M     LOW        HIGH   13.093  drugC
# 2   47   M     LOW        HIGH   10.114  drugC
# 3   28   F  NORMAL        HIGH    7.798  drugX
# 4   61   F     LOW        HIGH   18.043  DrugY

# %%
X=data.drop(columns='Drug',axis=1)
Y=data.drop(columns=['Age','Sex','BP','Cholesterol','Na_to_K'],axis=1)

# %%
X=X.replace("M",1)
X=X.replace("F",0)
X=X.replace("HIGH",1)
X=X.replace("LOW",0)

# %%
X.head()
# Out:
#    Age  Sex      BP Cholesterol  Na_to_K
# 0   23    0       1           1   25.355
# 1   47    1       0           1   13.093
# 2   47    1       0           1   10.114
# 3   28    0  NORMAL           1    7.798
# 4   61    0       0           1   18.043

# %%
X=X.replace('NORMAL',2)

# %%
model=keras.Sequential(
    [
        keras.layers.Flatten(input_shape=(5,)),
        keras.layers.Dense(20,activation='relu'),
        keras.layers.Dense(5,activation='sigmoid')
    ]
)

# %%
model.compile(optimizer='adam',metrics=['accuracy'],loss='sparse_categorical_crossentropy')

# %%
Y.shape
# Out:
# (200, 1)

# %%
print(Y)
# Out:
#       Drug
# 0    DrugY
# 1    drugC
# 2    drugC
# 3    drugX
# 4    DrugY
# ..     ...
# 195  drugC
# 196  drugC
# 197  drugX
# 198  drugX
# 199  drugX
#
# [200 rows x 1 columns]

# %%
Y=Y.replace("DrugY",0)
Y=Y.replace("drugX",1)
Y=Y.replace("drugC",2)
Y=Y.replace("drugA",3)
Y=Y.replace("drugB",4)

# %%
Y.head()
# Out:
#    Drug
# 0     0
# 1     2
# 2     2
# 3     1
# 4     0

# %%
model.fit(X,Y,validation_split=0.1,epochs=10)
# Out:
# Epoch 1/10
# 6/6 [==============================] - 1s 47ms/step - loss: 36.5807 - accuracy: 0.1167 - val_loss: 36.7816 - val_accuracy: 0.1000
# Epoch 2/10
# 6/6 [==============================] - 0s 8ms/step - loss: 34.2804 - accuracy: 0.1167 - val_loss: 34.3313 - val_accuracy: 0.1000
# Epoch 3/10
# 6/6 [==============================] - 0s 8ms/step - loss: 32.0069 - accuracy: 0.1167 - val_loss: 31.9329 - val_accuracy: 0.1000
# Epoch 4/10
# 6/6 [==============================] - 0s 10ms/step - loss: 29.7705 - accuracy: 0.1167 - val_loss: 29.5709 - val_accuracy: 0.1000
# Epoch 5/10
# 6/6 [==============================] - 0s 8ms/step - loss: 27.5750 - accuracy: 0.1167 - val_loss: 27.2382 - val_accuracy: 0.1000
# Epoch 6/10
# 6/6 [==============================] - 0s 12ms/step - loss: 25.4292 - accuracy: 0.1167 - val_loss: 24.9314 - val_accuracy: 0.1000
# Epoch 7/10
# 6/6 [==============================] - 0s 8ms/step - loss: 23.3217 - accuracy: 0.1167 - val_loss: 22.6568 - val_accuracy: 0.1000
# Epoch 8/10
# 6/6 [==============================] - 0s 8ms/step - loss: 21.2915 - accuracy: 0.1167 - val_loss: 20.4095 - val_accuracy: 0.1000
# Epoch 9/10
# 6/6 [==============================] - 0s 9ms/step - loss: 19.1682 - accuracy: 0.1167 - val_loss: 18.2454 - val_accuracy: 0.1000
# Epoch 10/10
# 6/6 [==============================] - 0s 7ms/step - loss: 17.1519 - accuracy: 0.1167 - val_loss: 16.1247 - val_accuracy: 0.1000
