# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import tensorflow as tf
tf.random.set_seed(3)
from tensorflow import keras
from sklearn.preprocessing import StandardScaler

# %%
data=pd.read_csv('/content/drug200.csv')

# %%
data.head()
# Out:
#    Age Sex      BP Cholesterol  Na_to_K   Drug
# 0   23   F    HIGH        HIGH   25.355  DrugY
# 1   47   M     LOW        HIGH   13.093  drugC
# 2   47   M     LOW        HIGH   10.114  drugC
# 3   28   F  NORMAL        HIGH    7.798  drugX
# 4   61   F     LOW        HIGH   18.043  DrugY

# %%
X=data.drop(columns='Drug',axis=1)
Y=data.drop(columns=['Age','Sex','BP','Cholesterol','Na_to_K'],axis=1)

# %%
X=X.replace("M",1)
X=X.replace("F",0)
X=X.replace("HIGH",1)
X=X.replace("LOW",0)

# %%
X.head()
# Out:
#    Age  Sex      BP Cholesterol  Na_to_K
# 0   23    0       1           1   25.355
# 1   47    1       0           1   13.093
# 2   47    1       0           1   10.114
# 3   28    0  NORMAL           1    7.798
# 4   61    0       0           1   18.043

# %%
X=X.replace('NORMAL',2)

# %%
model=keras.Sequential(
    [
        keras.layers.Flatten(input_shape=(5,)),
        keras.layers.Dense(20,activation='relu'),
        keras.layers.Dense(5,activation='sigmoid')
    ]
)

# %%
model.compile(optimizer='adam',metrics=['accuracy'],loss='sparse_categorical_crossentropy')

# %%
Y.shape
# Out:
# (200, 1)

# %%
print(Y)
# Out:
#       Drug
# 0    DrugY
# 1    drugC
# 2    drugC
# 3    drugX
# 4    DrugY
# ..     ...
# 195  drugC
# 196  drugC
# 197  drugX
# 198  drugX
# 199  drugX
#
# [200 rows x 1 columns]

# %%
Y=Y.replace("DrugY",0)
Y=Y.replace("drugX",1)
Y=Y.replace("drugC",2)
Y=Y.replace("drugA",3)
Y=Y.replace("drugB",4)

# %%
Y.head()
# Out:
#    Drug
# 0     0
# 1     2
# 2     2
# 3     1
# 4     0

# %%
model.fit(X,Y,validation_split=0.1,epochs=10)
# Out:
# Epoch 1/10
# 6/6 [==============================] - 1s 58ms/step - loss: 5.7804 - accuracy: 0.0611 - val_loss: 4.5570 - val_accuracy: 0.1000
# Epoch 2/10
# 6/6 [==============================] - 0s 13ms/step - loss: 4.7720 - accuracy: 0.0556 - val_loss: 3.7261 - val_accuracy: 0.0500
# Epoch 3/10
# 6/6 [==============================] - 0s 16ms/step - loss: 4.0779 - accuracy: 0.0500 - val_loss: 3.2964 - val_accuracy: 0.1500
# Epoch 4/10
# 6/6 [==============================] - 0s 17ms/step - loss: 3.7028 - accuracy: 0.1444 - val_loss: 3.0410 - val_accuracy: 0.2500
# Epoch 5/10
# 6/6 [==============================] - 0s 16ms/step - loss: 3.3768 - accuracy: 0.2000 - val_loss: 2.7795 - val_accuracy: 0.2500
# Epoch 6/10
# 6/6 [==============================] - 0s 14ms/step - loss: 3.0562 - accuracy: 0.2278 - val_loss: 2.4979 - val_accuracy: 0.2500
# Epoch 7/10
# 6/6 [==============================] - 0s 16ms/step - loss: 2.7124 - accuracy: 0.2444 - val_loss: 2.2308 - val_accuracy: 0.2500
# Epoch 8/10
# 6/6 [==============================] - 0s 15ms/step - loss: 2.4349 - accuracy: 0.2833 - val_loss: 1.9828 - val_accuracy: 0.4000
# Epoch 9/10
# 6/6 [==============================] - 0s 11ms/step - loss: 2.1396 - accuracy: 0.3111 - val_loss: 1.7905 - val_accuracy: 0.3500
# Epoch 10/10
# 6/6 [==============================] - 0s 15ms/step - loss: 1.9295 - accuracy: 0.3500 - val_loss: 1.6376 - val_accuracy: 0.4000

# %%
a=[]
for i in range(5):
  a.append(input())
# Out:
# 23
# 0
# 1
# 1
# 25

# %%
scaler=StandardScaler()

arr=np.array(a).reshape(1,-1)
scaler.fit(arr)
arrr=scaler.transform(arr)
prediction=model.predict(arrr)
print(np.argmax(prediction))
# Out:
# 1/1 [==============================] - 0s 95ms/step
# 1
